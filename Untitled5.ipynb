# %% [markdown]
# <a href="https://colab.research.google.com/github/HEBA2345678/DEPI-Project/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fd12c1b9-4296-456a-bfc0-05f2915bcee5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd12c1b9-4296-456a-bfc0-05f2915bcee5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# إن
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/

#
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !unzip -q customer-churn-dataset.zip
# Out:
# unzip:  cannot find or open customer-churn-dataset.zip, customer-churn-dataset.zip.zip or customer-churn-dataset.zip.ZIP.

# %%
# !kaggle datasets download -d muhammadshahidazeem/customer-churn-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/muhammadshahidazeem/customer-churn-dataset
# License(s): GPL-2.0
# ...
# 100% 6.66M/6.66M [00:00<00:00, 60.0MB/s]
# 100% 6.66M/6.66M [00:00<00:00, 59.7MB/s]

# %%
# !unzip -q /content/customer-churn-dataset.zip

# %%
import os
os.listdir("/content/")
# Out:
# ['.config',
#  'customer_churn_dataset-training-master.csv',
#  'customer_churn_dataset-testing-master.csv',
#  'customer-churn-dataset.zip',
#  'sample_data']

# %%
import pandas as pd

# تحميل بيانات التدريب
df_train = pd.read_csv("/content/customer_churn_dataset-training-master.csv")

# عرض أول 5 صفوف
df_train.head(10)
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
# 5         8.0  51.0    Male    33.0             25.0            9.0
# 6         9.0  58.0  Female    49.0             12.0            3.0
# 7        10.0  55.0  Female    37.0              8.0            4.0
# 8        11.0  39.0    Male    12.0              5.0            7.0
# 9        12.0  64.0  Female     3.0             25.0            2.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# ...

# %%
print(df_train.describe)
# Out:
# <bound method NDFrame.describe of         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0              2.0  30.0  Female    39.0             14.0            5.0
# 1              3.0  65.0  Female    49.0              1.0           10.0
# 2              4.0  55.0  Female    14.0              4.0            6.0
# 3              5.0  58.0    Male    38.0             21.0            7.0
# 4              6.0  23.0    Male    32.0             20.0            5.0
# ...            ...   ...     ...     ...              ...            ...
# 440828    449995.0  42.0    Male    54.0             15.0            1.0
# 440829    449996.0  25.0  Female     8.0             13.0            1.0
# 440830    449997.0  26.0    Male    35.0             27.0            1.0
# 440831    449998.0  28.0    Male    55.0             14.0            2.0
# 440832    449999.0  31.0    Male    48.0             20.0            1.0
#
# ...

# %%
print(df_train.info)
# Out:
# <bound method DataFrame.info of         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0              2.0  30.0  Female    39.0             14.0            5.0
# 1              3.0  65.0  Female    49.0              1.0           10.0
# 2              4.0  55.0  Female    14.0              4.0            6.0
# 3              5.0  58.0    Male    38.0             21.0            7.0
# 4              6.0  23.0    Male    32.0             20.0            5.0
# ...            ...   ...     ...     ...              ...            ...
# 440828    449995.0  42.0    Male    54.0             15.0            1.0
# 440829    449996.0  25.0  Female     8.0             13.0            1.0
# 440830    449997.0  26.0    Male    35.0             27.0            1.0
# 440831    449998.0  28.0    Male    55.0             14.0            2.0
# 440832    449999.0  31.0    Male    48.0             20.0            1.0
#
# ...

# %%
print(df_train.dtypes)
# Out:
# CustomerID           float64
# Age                  float64
# Gender                object
# Tenure               float64
# Usage Frequency      float64
# Support Calls        float64
# Payment Delay        float64
# Subscription Type     object
# Contract Length       object
# Total Spend          float64
# Last Interaction     float64
# Churn                float64
# dtype: object

# %%
print(df_train.isnull().sum())
# Out:
# CustomerID           1
# Age                  1
# Gender               1
# Tenure               1
# Usage Frequency      1
# Support Calls        1
# Payment Delay        1
# Subscription Type    1
# Contract Length      1
# Total Spend          1
# Last Interaction     1
# Churn                1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_train.hist(figsize=(12, 8))
plt.show()

#المحور الأفقي X-axis
#يمثل القيم العددية للبيانات، مثل الأعمار، الأسعار، الأوزان، الدرجات

#y-axis
#يمثل عدد التكرارات (Frequency) لكل فئة من البيانات

# %%
for col in df_train.select_dtypes(include=["object"]).columns:
    print(f"uniqe values {col}:")
    print(df_train[col].value_counts())
    print("\n")

    #بتطبق على الاعمده ال فيها string
    #include=["object"]
# Out:
# uniqe values Gender:
# Gender
# Male      250252
# Female    190580
# Name: count, dtype: int64
#
#
# uniqe values Subscription Type:
# Subscription Type
# Standard    149128
# Premium     148678
# Basic       143026
# Name: count, dtype: int64
#
#
# uniqe values Contract Length:
# Contract Length
# Annual       177198
# Quarterly    176530
# Monthly       87104
# Name: count, dtype: int64

# %%
for col in df_train.columns:
    print(f"uniqe values {col}:")
    print(df_train[col].value_counts())
    print("\n")
# Out:
# uniqe values CustomerID:
# CustomerID
# 2.0         1
# 301011.0    1
# 301009.0    1
# 301008.0    1
# 301007.0    1
#            ..
# 151752.0    1
# 151751.0    1
# 151750.0    1
# 151749.0    1
# 449999.0    1
# Name: count, Length: 440832, dtype: int64
#
#
# uniqe values Age:
# Age
# 50.0    13527
# 42.0    12578
# 40.0    12417
# 48.0    12379
# 47.0    12369
# 46.0    12368
# 44.0    12344
# 49.0    12331
# 41.0    12314
# 43.0    12298
# 45.0    12265
# 38.0    11181
# 31.0    11092
# 35.0    11062
# 36.0    11031
# 37.0    11024
# 33.0    10990
# 39.0    10961
# 30.0    10907
# 32.0    10885
# 34.0    10829
# 26.0     9692
# 25.0     9647
# 22.0     9639
# 28.0     9608
# 21.0     9574
# 29.0     9571
# 20.0     9553
# 23.0     9513
# 27.0     9472
# 24.0     9465
# 18.0     8219
# 19.0     8073
# 59.0     5573
# 63.0     5560
# 64.0     5496
# 55.0     5489
# 56.0     5477
# 54.0     5472
# 53.0     5467
# 65.0     5460
# 51.0     5437
# 60.0     5430
# 61.0     5407
# ...
